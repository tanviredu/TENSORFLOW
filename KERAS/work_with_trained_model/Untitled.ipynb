# %%
## cats and classification
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import tensorflow as tf
from tensorflow.keras.callbacks import TensorBoard

# %%
DATADIR='/home/vagrant/tensorflow_machine_learning/KERAS/work_with_trained_model'

# %%
CATAGORIES = ['Cat','Dog']

# %%
for catagories in CATAGORIES:
    path = os.path.join(DATADIR,catagories)   #adding path to cats and dog list
    for img in os.listdir(path):  ## getting a list of file in the DIR
        img_array = cv2.imread(os.path.join(path,img),cv2.IMREAD_GRAYSCALE)
        ## adding the image file with the path and then assign to variable
        ##and converted to GRAYSCALE cause it has low size
        plt.imshow(img_array,cmap='gray')
        #lets see the image
        break
    break

# %%
def prepare(filepath):
    IMG_SIZE=60
    img_array = cv2.imread(filepath,cv2.IMREAD_GRAYSCALE)
    new_array = cv2.resize(img_array,(IMG_SIZE,IMG_SIZE))
    return new_array.reshape(-1,IMG_SIZE,IMG_SIZE,1)

# %%
model = tf.keras.models.load_model('cnnmodel.model')

# %%
prediction = model.predict(prepare('Dog/63.jpg'))

# %%
print (prediction)   ###wrong prediction
# Out:
# [[1.]]

# %%
prediction = model.predict(prepare('Cat/65.jpg'))

# %%
print (prediction)  ## right prediction
# Out:
# [[0.99975926]]

# %%
### not the problen with the model this dogs is wired and model has a less number og photo
