# %%
## for numerical  and data frame manupulating
import numpy as np
import pandas as pd

# %%
## importing tensorflow directly we call it through KERAS
import tensorflow as tf

# %%
## importing data 
## dreating dataframe
df = pd.read_csv('data.csv')

# %%
df1=df[[]]
# Out:
#                   Date                                Spot Types of road  \
# 0          May 01,2018                   Hatirjheel, Dhaka     Boulevard
# 1         June 28,2017       Kalapani,Guimara, Khagrachari     Dirt Road
# 2     February 23,2018                    Mymensingh road      Dirt Road
# 3      February 7,2018              Sunamganj pagla bazar      Dirt Road
# 4     December 18,2018                      Gazipur sarak         street
# 5     December 11,2017                  Daudkandi, Comilla       Highway
# 6      January 04,2019                              Asulia        street
# 7     December 20,2018                   Comilla, chandina     Boulevard
# 8      January 06,2019                sarkira bangaler mor        street
# 9     December 19,2018               Chittagong KEPZ road      Boulevard
# 10    February 27,2018                 Kashiani, Gopalgonj       Highway
# 11     January 04,2019                            Tangail      Boulevard
# ...
